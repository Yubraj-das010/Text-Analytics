# %% [markdown]
# <h2><center>Assignment on Text Analytics Part I
# </center></h2>
# <h3><center>Creating Word Cloud
# </center></h3>
# <h3><center>Presented by Yubraj Das
# </center></h3>

# %% [markdown]
# #### Importing packages

# %%
import os
from wordcloud import WordCloud, STOPWORDS,ImageColorGenerator
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from stop_words import get_stop_words
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# #### Open the image & convert it into array format

# %%
original = np.array(Image.open('C:\\data\\Text Analytics\\bagh_mama2.png'))

# %% [markdown]
# #### Findind stop words to remove from the text

# %%
stop_words = get_stop_words('english')
stop_words.append('my_new_stop_word')
stop_words.remove('my_new_stop_word')

# %% [markdown]
# #### Preprocessing of the image for wordcloud

# %%
wc = WordCloud(background_color='white',
               mask=original,
               collocations=False,
               width=600,
               height=300,
               contour_width=3,
               contour_color='black',
               stopwords=stop_words)

# %% [markdown]
# #### Import & genertaing WordCloud

# %%
text = open('C:\data\Text Analytics\Tiger.txt').read()

# %%
wc.generate(text_file)

# %%
image_colors = ImageColorGenerator(original)
wc.recolor(color_func=image_colors)

# %% [markdown]
# #### Plotting WordCloud

# %%
plt.figure(figsize=(20, 10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
wc.to_file('wordcloud.png')
plt.show()

# %%
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.figure()
plt.imshow(original, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis("off")
plt.show()
